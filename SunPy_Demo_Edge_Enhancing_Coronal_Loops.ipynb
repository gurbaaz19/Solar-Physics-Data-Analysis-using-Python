# %% [markdown]
# <a href="https://colab.research.google.com/github/adityahridaysahu/Solar-Physics-Data-Analysis-using-Python/blob/main/SunPy_Demo_Edge_Enhancing_Coronal_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "sunpy[all]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sunpy[all]
#   Downloading sunpy-4.1.5-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (1.22.4)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (23.1)
# Collecting parfive[ftp]>=1.2.0
#   Downloading parfive-2.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: astropy>=4.2.1 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (5.2.2)
# Collecting drms>=0.6.1
#   Downloading drms-0.6.3-py3-none-any.whl (35 kB)
# Collecting glymur!=0.9.0,!=0.9.5,>=0.8.18
#   Downloading Glymur-0.12.3-py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (4.11.2)
# Collecting asdf>=2.8.0
#   Downloading asdf-2.15.0-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 30.2 MB/s eta 0:00:00
# Collecting reproject
#   Downloading reproject-0.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image>=0.16.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (0.19.3)
# Collecting zeep>=3.4.0
#   Downloading zeep-4.2.1-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.2/101.2 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (2.8.2)
# Requirement already satisfied: h5py>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (3.8.0)
# Requirement already satisfied: h5netcdf>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (1.1.0)
# Collecting asdf-astropy>=0.1.1
#   Downloading asdf_astropy-0.4.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (4.9.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (1.5.3)
# Requirement already satisfied: tqdm>=4.32.1 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (4.65.0)
# Requirement already satisfied: sqlalchemy>=1.3.4 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (2.0.9)
# Requirement already satisfied: scipy!=1.10.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (1.10.1)
# Collecting cdflib!=0.4.0,>=0.3.19
#   Downloading cdflib-0.4.9-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.7 MB/s eta 0:00:00
# Collecting mpl-animators>=1.0.0
#   Downloading mpl_animators-1.1.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: dask[array]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (2022.12.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from sunpy[all]) (3.7.1)
# Collecting asdf-transform-schemas>=0.3
#   Downloading asdf_transform_schemas-0.3.0-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.6/195.6 kB 20.3 MB/s eta 0:00:00
# Collecting jmespath>=0.6.2
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting asdf-unit-schemas>=0.1
#   Downloading asdf_unit_schemas-0.1.0-py3-none-any.whl (11 kB)
# Collecting asdf-standard>=1.0.1
#   Downloading asdf_standard-1.0.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.9/dist-packages (from asdf>=2.8.0->sunpy[all]) (6.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.9/dist-packages (from asdf>=2.8.0->sunpy[all]) (6.4.1)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from asdf>=2.8.0->sunpy[all]) (4.3.3)
# Collecting semantic-version>=2.8
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting asdf-coordinates-schemas>=0.1
#   Downloading asdf_coordinates_schemas-0.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.9/dist-packages (from astropy>=4.2.1->sunpy[all]) (2.0.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.8.0->sunpy[all]) (2.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (2.2.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.9/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (1.4.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (2023.4.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (8.1.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->sunpy[all]) (2022.7.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.8 MB/s eta 0:00:00
# Collecting aioftp>=0.17.1
#   Downloading aioftp-0.21.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.0->sunpy[all]) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.16.0->sunpy[all]) (2023.4.12)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.16.0->sunpy[all]) (2.25.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.16.0->sunpy[all]) (3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.16.0->sunpy[all]) (1.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.4->sunpy[all]) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.4->sunpy[all]) (4.5.0)
# Collecting requests-file>=1.5.1
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from zeep>=3.4.0->sunpy[all]) (3.2.0)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from zeep>=3.4.0->sunpy[all]) (2.27.1)
# Collecting requests-toolbelt>=0.7.1
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.2.0 in /usr/local/lib/python3.9/dist-packages (from zeep>=3.4.0->sunpy[all]) (23.1.0)
# Collecting astropy-healpix>=0.6
#   Downloading astropy_healpix-0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.11.4->asdf>=2.8.0->sunpy[all]) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<4.18,>=4.0.1->asdf>=2.8.0->sunpy[all]) (0.19.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.9/dist-packages (from partd>=0.3.10->dask[array]>=2.0.0->sunpy[all]) (1.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[all]) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[all]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[all]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[all]) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 15.7 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 21.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 11.7 MB/s eta 0:00:00
# Installing collected packages: semantic-version, multidict, jmespath, isodate, glymur, frozenlist, cdflib, async-timeout, asdf-standard, aioftp, yarl, requests-toolbelt, requests-file, asdf-unit-schemas, asdf-transform-schemas, aiosignal, zeep, mpl-animators, drms, astropy-healpix, asdf, aiohttp, reproject, parfive, asdf-coordinates-schemas, asdf-astropy, sunpy
# Successfully installed aioftp-0.21.4 aiohttp-3.8.4 aiosignal-1.3.1 asdf-2.15.0 asdf-astropy-0.4.0 asdf-coordinates-schemas-0.2.0 asdf-standard-1.0.3 asdf-transform-schemas-0.3.0 asdf-unit-schemas-0.1.0 astropy-healpix-0.7 async-timeout-4.0.2 cdflib-0.4.9 drms-0.6.3 frozenlist-1.3.3 glymur-0.12.3 isodate-0.6.1 jmespath-1.0.1 mpl-animators-1.1.0 multidict-6.0.4 parfive-2.0.2 reproject-0.10.0 requests-file-1.5.1 requests-toolbelt-0.10.1 semantic-version-2.10.0 sunpy-4.1.5 yarl-1.9.1 zeep-4.2.1

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage

import astropy.units as u
from astropy.coordinates import SkyCoord

import sunpy.map
from sunpy.data.sample import AIA_171_IMAGE
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# AIA20110607_063302_0171_lowres.fits:   0%|          | 0.00/973k [00:00<?, ?B/s]

# %%
aia = sunpy.map.Map(AIA_171_IMAGE)
bottom_left = SkyCoord(750 * u.arcsec, -200 * u.arcsec, frame=aia.coordinate_frame)
top_right = SkyCoord(1500 * u.arcsec, 550 * u.arcsec, frame=aia.coordinate_frame)
aia_smap = aia.submap(bottom_left, top_right=top_right)

# %%
sx = ndimage.sobel(aia_smap.data, axis=0, mode='constant')
sy = ndimage.sobel(aia_smap.data, axis=1, mode='constant')
edge_enhanced_im = np.hypot(sx, sy)

# %%
edge_map = sunpy.map.Map(edge_enhanced_im, aia_smap.meta)

# %%
plt.figure()
edge_map.plot()
plt.show()
