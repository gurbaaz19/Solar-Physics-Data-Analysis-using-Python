# %% [markdown]
# as<a href="https://colab.research.google.com/github/adityahridaysahu/Solar-Physics-Data-Analysis-using-Python/blob/main/SunPy_Demo_Edge_Enhancing_Coronal_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "sunpy[all]"
# Out:
# Requirement already satisfied: sunpy[all] in ./venv/lib/python3.11/site-packages (4.1.5)
# Requirement already satisfied: astropy>=4.2.1 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (5.2.2)
# Requirement already satisfied: numpy>=1.17.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (1.24.3)
# Requirement already satisfied: packaging>=19.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (23.1)
# Requirement already satisfied: parfive[ftp]>=1.2.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (2.0.2)
# Requirement already satisfied: asdf-astropy>=0.1.1 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.4.0)
# Requirement already satisfied: asdf>=2.8.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (2.15.0)
# Requirement already satisfied: dask[array]>=2.0.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (2023.4.0)
# Requirement already satisfied: sqlalchemy>=1.3.4 in /usr/lib/python3/dist-packages (from sunpy[all]) (1.4.46)
# Requirement already satisfied: scikit-image>=0.16.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.20.0)
# Requirement already satisfied: scipy!=1.10.0,>=1.3.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (1.10.1)
# Requirement already satisfied: glymur!=0.9.0,!=0.9.5,>=0.8.18 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.12.3)
# Requirement already satisfied: lxml>=4.8.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (4.9.2)
# Requirement already satisfied: matplotlib>=3.3.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (3.7.1)
# Requirement already satisfied: mpl-animators>=1.0.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (1.1.0)
# Requirement already satisfied: reproject in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.10.0)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (4.12.2)
# Requirement already satisfied: drms>=0.6.1 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/lib/python3/dist-packages (from sunpy[all]) (2.8.2)
# Requirement already satisfied: tqdm>=4.32.1 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (4.65.0)
# Requirement already satisfied: zeep>=3.4.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (4.2.1)
# Requirement already satisfied: cdflib!=0.4.0,>=0.3.19 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (0.4.9)
# Requirement already satisfied: h5netcdf>=0.8.1 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (1.1.0)
# Requirement already satisfied: h5py>=3.1.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (3.8.0)
# Requirement already satisfied: pandas>=1.0.0 in ./venv/lib/python3.11/site-packages (from sunpy[all]) (2.0.0)
# Requirement already satisfied: asdf-standard>=1.0.1 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (1.0.3)
# Requirement already satisfied: asdf-transform-schemas>=0.3 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (0.3.0)
# Requirement already satisfied: asdf-unit-schemas>=0.1 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (0.1.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (6.6.0)
# Requirement already satisfied: jmespath>=0.6.2 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (1.0.1)
# Requirement already satisfied: jsonschema<4.18,>=4.0.1 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (4.17.3)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/lib/python3/dist-packages (from asdf>=2.8.0->sunpy[all]) (6.0)
# Requirement already satisfied: semantic-version>=2.8 in ./venv/lib/python3.11/site-packages (from asdf>=2.8.0->sunpy[all]) (2.10.0)
# Requirement already satisfied: asdf-coordinates-schemas>=0.1 in ./venv/lib/python3.11/site-packages (from asdf-astropy>=0.1.1->sunpy[all]) (0.2.0)
# Requirement already satisfied: pyerfa>=2.0 in ./venv/lib/python3.11/site-packages (from astropy>=4.2.1->sunpy[all]) (2.0.0.3)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.11/site-packages (from beautifulsoup4>=4.8.0->sunpy[all]) (2.4.1)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from dask[array]>=2.0.0->sunpy[all]) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in ./venv/lib/python3.11/site-packages (from dask[array]>=2.0.0->sunpy[all]) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in ./venv/lib/python3.11/site-packages (from dask[array]>=2.0.0->sunpy[all]) (2023.4.0)
# Requirement already satisfied: partd>=1.2.0 in ./venv/lib/python3.11/site-packages (from dask[array]>=2.0.0->sunpy[all]) (1.4.0)
# Requirement already satisfied: toolz>=0.8.2 in ./venv/lib/python3.11/site-packages (from dask[array]>=2.0.0->sunpy[all]) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->sunpy[all]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->sunpy[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->sunpy[all]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->sunpy[all]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->sunpy[all]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.0->sunpy[all]) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.11/site-packages (from pandas>=1.0.0->sunpy[all]) (2023.3)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.11/site-packages (from parfive[ftp]>=1.2.0->sunpy[all]) (3.8.4)
# Requirement already satisfied: aioftp>=0.17.1 in ./venv/lib/python3.11/site-packages (from parfive[ftp]>=1.2.0->sunpy[all]) (0.21.4)
# Requirement already satisfied: networkx>=2.8 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.16.0->sunpy[all]) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.16.0->sunpy[all]) (2.28.0)
# Requirement already satisfied: tifffile>=2019.7.26 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.16.0->sunpy[all]) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.16.0->sunpy[all]) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in ./venv/lib/python3.11/site-packages (from scikit-image>=0.16.0->sunpy[all]) (0.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/lib/python3/dist-packages (from sqlalchemy>=1.3.4->sunpy[all]) (2.0.1)
# Requirement already satisfied: attrs>=17.2.0 in ./venv/lib/python3.11/site-packages (from zeep>=3.4.0->sunpy[all]) (23.1.0)
# Requirement already satisfied: isodate>=0.5.4 in ./venv/lib/python3.11/site-packages (from zeep>=3.4.0->sunpy[all]) (0.6.1)
# Requirement already satisfied: platformdirs>=1.4.0 in ./venv/lib/python3.11/site-packages (from zeep>=3.4.0->sunpy[all]) (3.2.0)
# Requirement already satisfied: requests>=2.7.0 in /usr/lib/python3/dist-packages (from zeep>=3.4.0->sunpy[all]) (2.28.1)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /usr/lib/python3/dist-packages (from zeep>=3.4.0->sunpy[all]) (0.10.1)
# Requirement already satisfied: requests-file>=1.5.1 in ./venv/lib/python3.11/site-packages (from zeep>=3.4.0->sunpy[all]) (1.5.1)
# Requirement already satisfied: astropy-healpix>=0.6 in ./venv/lib/python3.11/site-packages (from reproject->sunpy[all]) (0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.11.4->asdf>=2.8.0->sunpy[all]) (1.0.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate>=0.5.4->zeep>=3.4.0->sunpy[all]) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.11/site-packages (from jsonschema<4.18,>=4.0.1->asdf>=2.8.0->sunpy[all]) (0.19.3)
# Requirement already satisfied: locket in ./venv/lib/python3.11/site-packages (from partd>=1.2.0->dask[array]>=2.0.0->sunpy[all]) (1.0.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (1.9.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (1.3.1)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->parfive[ftp]>=1.2.0->sunpy[all]) (3.3)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from zipp>=0.5->importlib-metadata>=4.11.4->asdf>=2.8.0->sunpy[all]) (8.10.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage

import astropy.units as u
from astropy.coordinates import SkyCoord

import sunpy.map
from sunpy.data.sample import AIA_171_IMAGE

# %%
aia = sunpy.map.Map(AIA_171_IMAGE)
bottom_left = SkyCoord(750 * u.arcsec, -200 * u.arcsec, frame=aia.coordinate_frame)
top_right = SkyCoord(1500 * u.arcsec, 550 * u.arcsec, frame=aia.coordinate_frame)
aia_smap = aia.submap(bottom_left, top_right=top_right)

# %%
sx = ndimage.sobel(aia_smap.data, axis=0, mode='constant')
sy = ndimage.sobel(aia_smap.data, axis=1, mode='constant')
edge_enhanced_im = np.hypot(sx, sy)

# %%
edge_map = sunpy.map.Map(edge_enhanced_im, aia_smap.meta)

# %%
plt.figure()
edge_map.plot()
plt.show()
